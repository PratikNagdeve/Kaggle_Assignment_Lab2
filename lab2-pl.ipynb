# %%
# 1. Install the package if not already
# !pip install kagglehub

# 2. Import
import kagglehub

# 3. Download the dataset
# This will download the latest version of the dataset
path = kagglehub.dataset_download("rabieelkharoua/human-activity-classification-dataset")

# 4. Check downloaded files path
print("Path to dataset files:", path)
# Out:
# ...
# Path to dataset files: /kaggle/input/human-activity-classification-dataset

# %%
import os

# List all files in the path
os.listdir(path)
# Out:
# ['wisdm-dataset', 'WISDM-dataset-description.pdf']

# %%
import os

dataset_folder = os.path.join(path, 'wisdm-dataset')
os.listdir(dataset_folder)
# Out:
# ['wisdm-dataset']

# %%
import os

# Path to the folder
dataset_folder = os.path.join(path, 'wisdm-dataset')

# List all files inside
os.listdir(dataset_folder)
# Out:
# ['wisdm-dataset']
